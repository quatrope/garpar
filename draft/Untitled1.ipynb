# %%
import garpar as gp

# %%
pf = gp.datasets.load_MERVAL()
# Out:
# /home/divasco/Documents/Tesina/garpar/garpar/datasets/data/__init__.py:22: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method=imputation, inplace=True)

# %%
pf.plot(legend=False)
# Out:
# <Axes: title={'center': 'Price'}, xlabel='Days'>

# %%
pf.plot.heatmap(returns=False)
# Out:
# <Axes: title={'center': 'Price'}, xlabel='Stocks', ylabel='Days'>

# %%
petroleo = gp.datasets.RissoNormal(entropy=.8)
granos = gp.datasets.RissoNormal(entropy=.3)

ms = gp.datasets.MultiSector([["Petroleo", petroleo], ["Granos", granos]])

# %%
pf = ms.make_portfolio()

# %%
pf.plot.whist()
# Out:
# <Axes: title={'center': 'Weights'}, ylabel='Count'>

# %%
mk = gp.optimize.BlackLitterman()

# %%
mk.optimize(pf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 mk.optimize(pf)
#
# File ~/Documents/Tesina/garpar/garpar/optimize.py:31, in OptimizerABC.optimize(self, pf)
#      29 def optimize(self, pf):
#      30     """Skeleton for optimize."""
# ---> 31     weights, metadata = self._calculate_weights(pf)
#      32     return pf.copy(weights=weights, optimizer=metadata)
#
# File ~/Documents/Tesina/garpar/garpar/optimize.py:119, in BlackLitterman._calculate_weights(self, pf)
#     118 def _calculate_weights(self, pf):
# --> 119     blm = self._get_optimizer(pf)
#     120     risk_aversion = self.risk_aversion
#     122     weights_dict = blm.bl_weights(risk_aversion)
#
# File ~/Documents/Tesina/garpar/garpar/optimize.py:114, in BlackLitterman._get_optimizer(self, pf)
#     111 P = self.P
#     112 Q = self.Q
# --> 114 return pypfopt.BlackLittermanModel(
# ...

# %%
pf.risk.stock_beta()
# Out:
# Stocks
# Petroleo_S0    0.836950
# Petroleo_S1    0.775054
# Petroleo_S2    1.263345
# Petroleo_S3    1.180794
# Petroleo_S4    1.058926
# Granos_S0      1.113874
# Granos_S1      1.034943
# Granos_S2      0.929287
# Granos_S3      1.011129
# Granos_S4      0.795698
# Name: beta, dtype: float64
